# %%
import tensorflow as tf
print(f"Num Gpu Avaiable Are : {len(tf.config.list_physical_devices('GPU'))}")
# Out:
# Num Gpu Avaiable Are : 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
import cv2
import os, glob
import tensorflow as tf
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D,GlobalAveragePooling2D,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
data="data"
label=[]
for file in os.listdir(data):
    if file[0] =='.':
        continue
    label+=[file]
print(label)
print(len(label))
# Out:
# ['battery', 'biological', 'brown-glass', 'cardboard', 'clothes', 'green-glass', 'metal', 'paper', 'plastic', 'shoes', 'trash', 'white-glass']
# 12

# %%
img_height,img_width=256,256
batch_size=20

train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(data,
                                                target_size=(img_height,img_width),
                                                batch_size=batch_size,
                                                class_mode='categorical',
                                               )
test_generator = train_datagen.flow_from_directory(data,
                                                target_size=(img_height,img_width),
                                                batch_size=batch_size,
                                                class_mode='categorical',
                               
                                               )
# Out:
# Found 15515 images belonging to 12 classes.
# Found 15515 images belonging to 12 classes.

# %%
precision=tf.keras.metrics.Precision()
recall=tf.keras.metrics.Recall()
sensitivity=tf.keras.metrics.SensitivityAtSpecificity(0.1)
specificity=tf.keras.metrics.SpecificityAtSensitivity(0.1)

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (img_height,img_width,3)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))

model.add(Dense(12, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               67109120
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 67,195,692
# Trainable params: 67,195,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy',precision,recall,sensitivity,specificity])
hist=model.fit(train_generator,epochs=50,validation_data=test_generator)
# Out:
# Epoch 1/50
# 776/776 [==============================] - 452s 566ms/step - loss: 1.4515 - accuracy: 0.5324 - precision: 0.7712 - recall: 0.3484 - sensitivity_at_specificity: 0.9880 - specificity_at_sensitivity: 0.9996 - val_loss: 1.0054 - val_accuracy: 0.6629 - val_precision: 0.8271 - val_recall: 0.5351 - val_sensitivity_at_specificity: 0.9941 - val_specificity_at_sensitivity: 1.0000
# Epoch 2/50
# 776/776 [==============================] - 207s 266ms/step - loss: 0.8947 - accuracy: 0.7083 - precision: 0.8239 - recall: 0.6006 - sensitivity_at_specificity: 0.9901 - specificity_at_sensitivity: 0.9999 - val_loss: 0.5240 - val_accuracy: 0.8333 - val_precision: 0.9067 - val_recall: 0.7600 - val_sensitivity_at_specificity: 0.9961 - val_specificity_at_sensitivity: 1.0000
# Epoch 3/50
# 776/776 [==============================] - 205s 264ms/step - loss: 0.5017 - accuracy: 0.8367 - precision: 0.8913 - recall: 0.7851 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - val_loss: 0.2630 - val_accuracy: 0.9236 - val_precision: 0.9514 - val_recall: 0.8903 - val_sensitivity_at_specificity: 0.9990 - val_specificity_at_sensitivity: 1.0000
# Epoch 4/50
# 776/776 [==============================] - 197s 253ms/step - loss: 0.2242 - accuracy: 0.9296 - precision: 0.9475 - recall: 0.9140 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0912 - val_accuracy: 0.9747 - val_precision: 0.9799 - val_recall: 0.9697 - val_sensitivity_at_specificity: 0.9981 - val_specificity_at_sensitivity: 0.9999
# Epoch 5/50
# 776/776 [==============================] - 215s 277ms/step - loss: 0.1211 - accuracy: 0.9623 - precision: 0.9687 - recall: 0.9560 - sensitivity_at_specificity: 0.9976 - specificity_at_sensitivity: 0.9999 - val_loss: 0.1327 - val_accuracy: 0.9589 - val_precision: 0.9681 - val_recall: 0.9522 - val_sensitivity_at_specificity: 0.9964 - val_specificity_at_sensitivity: 0.9999
# Epoch 6/50
# 776/776 [==============================] - 196s 253ms/step - loss: 0.1301 - accuracy: 0.9617 - precision: 0.9671 - recall: 0.9568 - sensitivity_at_specificity: 0.9972 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0463 - val_accuracy: 0.9871 - val_precision: 0.9894 - val_recall: 0.9849 - val_sensitivity_at_specificity: 0.9990 - val_specificity_at_sensitivity: 0.9999
# Epoch 7/50
# 776/776 [==============================] - 194s 250ms/step - loss: 0.0718 - accuracy: 0.9812 - precision: 0.9841 - recall: 0.9794 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0409 - val_accuracy: 0.9867 - val_precision: 0.9884 - val_recall: 0.9854 - val_sensitivity_at_specificity: 0.9993 - val_specificity_at_sensitivity: 0.9999
# Epoch 8/50
# 776/776 [==============================] - 200s 257ms/step - loss: 0.0657 - accuracy: 0.9807 - precision: 0.9830 - recall: 0.9789 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0484 - val_accuracy: 0.9870 - val_precision: 0.9884 - val_recall: 0.9859 - val_sensitivity_at_specificity: 0.9987 - val_specificity_at_sensitivity: 0.9999
# Epoch 9/50
# 776/776 [==============================] - 245s 316ms/step - loss: 0.0667 - accuracy: 0.9825 - precision: 0.9840 - recall: 0.9813 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0313 - val_accuracy: 0.9908 - val_precision: 0.9914 - val_recall: 0.9901 - val_sensitivity_at_specificity: 0.9990 - val_specificity_at_sensitivity: 0.9999
# Epoch 10/50
# 776/776 [==============================] - 191s 246ms/step - loss: 0.0739 - accuracy: 0.9787 - precision: 0.9825 - recall: 0.9760 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0321 - val_accuracy: 0.9907 - val_precision: 0.9913 - val_recall: 0.9903 - val_sensitivity_at_specificity: 0.9990 - val_specificity_at_sensitivity: 0.9999
# Epoch 11/50
# 776/776 [==============================] - 187s 241ms/step - loss: 0.0312 - accuracy: 0.9916 - precision: 0.9921 - recall: 0.9908 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0237 - val_accuracy: 0.9923 - val_precision: 0.9926 - val_recall: 0.9918 - val_sensitivity_at_specificity: 0.9994 - val_specificity_at_sensitivity: 1.0000
# Epoch 12/50
# 776/776 [==============================] - 199s 256ms/step - loss: 0.0692 - accuracy: 0.9820 - precision: 0.9833 - recall: 0.9809 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0176 - val_accuracy: 0.9954 - val_precision: 0.9956 - val_recall: 0.9953 - val_sensitivity_at_specificity: 0.9994 - val_specificity_at_sensitivity: 1.0000
# Epoch 13/50
# 776/776 [==============================] - 196s 253ms/step - loss: 0.0637 - accuracy: 0.9823 - precision: 0.9837 - recall: 0.9812 - sensitivity_at_specificity: 0.9974 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0218 - val_accuracy: 0.9933 - val_precision: 0.9936 - val_recall: 0.9929 - val_sensitivity_at_specificity: 0.9997 - val_specificity_at_sensitivity: 1.0000
# Epoch 14/50
# 776/776 [==============================] - 193s 249ms/step - loss: 0.0471 - accuracy: 0.9892 - precision: 0.9901 - recall: 0.9888 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0362 - val_accuracy: 0.9910 - val_precision: 0.9914 - val_recall: 0.9902 - val_sensitivity_at_specificity: 0.9988 - val_specificity_at_sensitivity: 0.9999
# Epoch 15/50
# 776/776 [==============================] - 201s 259ms/step - loss: 0.0447 - accuracy: 0.9882 - precision: 0.9889 - recall: 0.9878 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0672 - val_accuracy: 0.9796 - val_precision: 0.9809 - val_recall: 0.9792 - val_sensitivity_at_specificity: 0.9976 - val_specificity_at_sensitivity: 0.9998
# Epoch 16/50
# 776/776 [==============================] - 186s 239ms/step - loss: 0.0513 - accuracy: 0.9865 - precision: 0.9874 - recall: 0.9861 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0379 - val_accuracy: 0.9902 - val_precision: 0.9910 - val_recall: 0.9899 - val_sensitivity_at_specificity: 0.9987 - val_specificity_at_sensitivity: 0.9999
# Epoch 17/50
# 776/776 [==============================] - 188s 243ms/step - loss: 0.0311 - accuracy: 0.9920 - precision: 0.9924 - recall: 0.9916 - sensitivity_at_specificity: 0.9988 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0212 - val_accuracy: 0.9930 - val_precision: 0.9944 - val_recall: 0.9921 - val_sensitivity_at_specificity: 0.9996 - val_specificity_at_sensitivity: 1.0000
# Epoch 18/50
# 776/776 [==============================] - 198s 255ms/step - loss: 0.0258 - accuracy: 0.9925 - precision: 0.9932 - recall: 0.9921 - sensitivity_at_specificity: 0.9992 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0531 - val_accuracy: 0.9849 - val_precision: 0.9864 - val_recall: 0.9840 - val_sensitivity_at_specificity: 0.9977 - val_specificity_at_sensitivity: 0.9998
# Epoch 19/50
# 776/776 [==============================] - 194s 249ms/step - loss: 0.0491 - accuracy: 0.9888 - precision: 0.9895 - recall: 0.9883 - sensitivity_at_specificity: 0.9973 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0100 - val_accuracy: 0.9977 - val_precision: 0.9978 - val_recall: 0.9975 - val_sensitivity_at_specificity: 0.9996 - val_specificity_at_sensitivity: 1.0000
# Epoch 20/50
# 776/776 [==============================] - 200s 258ms/step - loss: 0.0243 - accuracy: 0.9946 - precision: 0.9948 - recall: 0.9945 - sensitivity_at_specificity: 0.9988 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0108 - val_accuracy: 0.9973 - val_precision: 0.9975 - val_recall: 0.9970 - val_sensitivity_at_specificity: 0.9996 - val_specificity_at_sensitivity: 1.0000
# Epoch 21/50
# 776/776 [==============================] - 198s 255ms/step - loss: 0.0428 - accuracy: 0.9896 - precision: 0.9901 - recall: 0.9893 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0558 - val_accuracy: 0.9868 - val_precision: 0.9875 - val_recall: 0.9861 - val_sensitivity_at_specificity: 0.9972 - val_specificity_at_sensitivity: 0.9998
# Epoch 22/50
# 776/776 [==============================] - 193s 248ms/step - loss: 0.0333 - accuracy: 0.9929 - precision: 0.9934 - recall: 0.9926 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 0.9999 - val_loss: 0.0056 - val_accuracy: 0.9989 - val_precision: 0.9990 - val_recall: 0.9988 - val_sensitivity_at_specificity: 0.9998 - val_specificity_at_sensitivity: 1.0000
# Epoch 23/50
# 776/776 [==============================] - 191s 246ms/step - loss: 0.0389 - accuracy: 0.9906 - precision: 0.9914 - recall: 0.9901 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 0.9999 - val_loss: 0.
- val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 1.0000
# Epoch 50/50
# 776/776 [==============================] - 206s 266ms/step - loss: 0.0326 - accuracy: 0.9945 - precision: 0.9948 - recall: 0.9941 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9998 - val_loss: 0.0373 - val_accuracy: 0.9964 - val_precision: 0.9965 - val_recall: 0.9962 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9998

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['accuracy'], color='b', label="Training accuracy")
ax[0].plot(hist.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['precision'], color='b', label="Training precision")
ax[0].plot(hist.history['val_precision'], color='r',label="Validation precision")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['recall'], color='b', label="Training recall")
ax[0].plot(hist.history['val_recall'], color='r',label="Validation recall")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['sensitivity_at_specificity'], color='b', label="Training sensitivity")
ax[0].plot(hist.history['val_sensitivity_at_specificity'], color='r',label="Validation sensitivity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['specificity_at_sensitivity'], color='b', label="Training specificity")
ax[0].plot(hist.history['val_specificity_at_sensitivity'], color='r',label="Validation specificity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
model.save("./models/CNN.h5")

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)
model_predict = model.predict_generator(test_generator,steps = nb_samples, verbose=2)
# Out:
# c:\Users\0258\.conda\envs\deepfake\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15515 batches). You may need to use the repeat() function when building your dataset.
# 15515/15515 - 78s

# %%
y_true = test_generator.classes
y_pred = model_predict.argmax(axis=1)
plot_confusion_matrix(y_true, y_pred, classes=['battery', 'biological', 'brown-glass', 'cardboard', 'clothes', 'green-glass', 'metal', 'paper', 'plastic', 'shoes', 'trash', 'white-glass'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[  53   64   38   41  320   36   53   66   56  122   44   52]
#  [  52   60   48   72  336   39   53   67   38  132   39   49]
#  [  38   41   20   27  212   28   34   36   34   85   24   28]
#  [  66   51   31   39  297   45   53   70   59  105   34   41]
#  [ 318  336  212  323 1849  216  240  347  268  687  241  288]
#  [  42   40   29   37  222   20   22   41   40   80   29   27]
#  [  55   42   30   52  253   31   45   46   44   91   39   41]
#  [  76   72   36   64  353   51   51   78   62  125   33   49]
#  [  39   58   31   46  289   46   43   59   61  114   45   34]
#  [ 125  114   63  109  686   85   96  151  108  250  102   88]
#  [  37   46   35   42  241   26   35   46   31   82   34   42]
#  [  47   60   28   40  261   31   44   41   45  105   35   38]]
# <AxesSubplot:title={'center':'Confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.06      0.06       945
#            1       0.06      0.06      0.06       985
#            2       0.03      0.03      0.03       607
#            3       0.04      0.04      0.04       891
#            4       0.35      0.35      0.35      5325
#            5       0.03      0.03      0.03       629
#            6       0.06      0.06      0.06       769
#            7       0.07      0.07      0.07      1050
#            8       0.07      0.07      0.07       865
#            9       0.13      0.13      0.13      1977
#           10       0.05      0.05      0.05       697
#           11       0.05      0.05      0.05       775
#
#     accuracy                           0.16     15515
#    macro avg       0.08      0.08      0.08     15515
# weighted avg       0.16      0.16      0.16     15515
